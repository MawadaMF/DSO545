# %%
conda install -c plotly plotly=5.4.0
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env
#
#   added / updated specs:
#     - plotly=5.4.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.10.26 |       hecd8cb5_2         115 KB
#     certifi-2021.10.8          |   py39hecd8cb5_0         151 KB
#     plotly-5.4.0               |             py_0         6.8 MB  plotly
#     tenacity-8.0.1             |   py39hecd8cb5_0          33 KB
#     ------------------------------------------------------------
#                                            Total:         7.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly             plotly/noarch::plotly-5.4.0-py_0
#   tenacity           pkgs/main/osx-64::tenacity-8.0.1-py39hecd8cb5_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                       2021.7.5-hecd8cb5_1 --> 2021.10.26-hecd8cb5_2
#   certifi                          2021.5.30-py39hecd8cb5_0 --> 2021.10.8-py39hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# plotly-5.4.0         | 6.8 MB    | ##################################### | 100%
# tenacity-8.0.1       | 33 KB     | ##################################### | 100%
# ca-certificates-2021 | 115 KB    | ##################################### | 100%
# certifi-2021.10.8    | 151 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash
# Out:
# Collecting dash
#   Using cached dash-2.0.0-py3-none-any.whl (7.3 MB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0.tar.gz (3.4 kB)
# Requirement already satisfied: plotly>=5.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash) (5.4.0)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0.tar.gz (3.4 kB)
# Collecting flask-compress
#   Using cached Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# Collecting Flask>=1.0.4
#   Downloading Flask-2.0.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.2 MB/s
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0.tar.gz (3.8 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 13.7 MB/s
# Requirement already satisfied: Jinja2>=3.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Flask>=1.0.4->dash) (3.0.1)
# Collecting click>=7.1.2
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 11.0 MB/s
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp39-cp39-macosx_10_9_x86_64.whl (421 kB)
#      |████████████████████████████████| 421 kB 3.7 MB/s
# Building wheels for collected packages: dash-core-components, dash-html-components, dash-table
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-2.0.0-py3-none-any.whl size=3821 sha256=3cee9544e8173b92f002fee2a2b1e9387330d04c3dcfdf5625fb4e9877a6a6f1
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/2b/37/e9/4b5a8c878a47590de4dcf6bdc5a158788a1c17bea578a3ab60
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-2.0.0-py3-none-any.whl size=4089 sha256=28b1663b80484869bc1c7b3e26d3662b3773be5470b3ada2d0ef7dae0c5a0e92
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/4d/22/3e/d58dc9820aeffc7b7193d04a63b08f585eef4a1ce836d69141
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-5.0.0-py3-none-any.whl size=3911 sha256=930cb30977fa9cdaa481734d41f733c0830ca0a2624636073f95dabc9d827b37
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/1f/91/7e/015c42538da07aeb06576caca14da7c7416e9275a51fc85811
# Successfully built dash-core-components dash-html-components dash-table
# Installing collected packages: Werkzeug, itsdangerous, click, Flask, brotli, flask-compress, dash-table, dash-html-components, dash-core-components, dash
# Successfully installed Flask-2.0.2 Werkzeug-2.0.2 brotli-1.0.9 click-8.0.3 dash-2.0.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.10.1 itsdangerous-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-dash
# Out:
# Collecting jupyter-dash
#   Downloading jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: ipykernel in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-dash) (6.2.0)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.5 MB/s
# Requirement already satisfied: dash in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-dash) (2.0.0)
# Collecting ansi2html
#   Downloading ansi2html-1.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: flask in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-dash) (2.0.2)
# Requirement already satisfied: ipython in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-dash) (7.27.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash->jupyter-dash) (5.4.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: flask-compress in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash->jupyter-dash) (1.10.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask->jupyter-dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask->jupyter-dash) (8.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask->jupyter-dash) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.0.1)
# Requirement already satisfied: six in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.0.1)
# Requirement already satisfied: brotli in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (1.4.1)
# Requirement already satisfied: appnope in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (6.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (5.0.5)
# Requirement already satisfied: jupyter-client<8.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipykernel->jupyter-dash) (7.0.1)
# Requirement already satisfied: pexpect>4.3 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: decorator in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (58.0.4)
# Requirement already satisfied: backcall in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pygments in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from ipython->jupyter-dash) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.2)
# Requirement already satisfied: entrypoints in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter-dash) (4.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from traitlets<6.0,>=4.1.0->ipykernel->jupyter-dash) (0.2.0)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 22.7 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from requests->jupyter-dash) (2021.10.8)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 4.2 MB/s
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.8-py3-none-any.whl (39 kB)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=ad2d04280c258e4e487a7ae61781b8b25bc845f58481a0b3342b84215e66dfd2
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/ce/18/7f/e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# Installing collected packages: urllib3, idna, charset-normalizer, retrying, requests, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.6.0 charset-normalizer-2.0.8 idna-3.3 jupyter-dash-0.4.0 requests-2.26.0 retrying-1.3.3 urllib3-1.26.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-bootstrap-components
# Out:
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-1.0.0-py3-none-any.whl (207 kB)
# Requirement already satisfied: dash>=2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (5.4.0)
# Requirement already satisfied: Flask>=1.0.4 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.0.2)
# Requirement already satisfied: dash-table==5.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (5.0.0)
# Requirement already satisfied: flask-compress in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (1.10.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: Werkzeug>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (3.0.1)
# Requirement already satisfied: click>=7.1.2 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (8.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.0.1)
# Requirement already satisfied: six in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash>=2.0.0->dash-bootstrap-components) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from plotly>=5.0.0->dash>=2.0.0->dash-bootstrap-components) (8.0.1)
# Requirement already satisfied: brotli in /Users/meilanloh/Desktop/MLprojects/Bulldozer-price-prediction-project/env/lib/python3.9/site-packages (from flask-compress->dash>=2.0.0->dash-bootstrap-components) (1.0.9)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash==0.42.0
# Out:
# Collecting dash==0.42.0
#   Downloading dash-0.42.0.tar.gz (40 kB)
#      |████████████████████████████████| 40 kB 3.4 MB/s
# Requirement already satisfied: Flask>=0.12 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from dash==0.42.0) (1.1.2)
# Requirement already satisfied: flask-compress in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from dash==0.42.0) (1.10.1)
# Requirement already satisfied: plotly in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from dash==0.42.0) (5.3.1)
# Collecting dash_renderer==0.23.0
#   Downloading dash_renderer-0.23.0.tar.gz (2.3 MB)
#      |████████████████████████████████| 2.3 MB 6.6 MB/s
# Collecting dash-core-components==0.47.0
#   Downloading dash_core_components-0.47.0.tar.gz (4.4 MB)
#      |████████████████████████████████| 4.4 MB 15.5 MB/s
# Collecting dash-html-components==0.16.0
#   Downloading dash_html_components-0.16.0.tar.gz (555 kB)
#      |████████████████████████████████| 555 kB 15.4 MB/s
# Collecting dash-table==3.6.0
#   Downloading dash_table-3.6.0.tar.gz (468 kB)
#      |████████████████████████████████| 468 kB 23.0 MB/s
# Requirement already satisfied: click>=5.1 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from Flask>=0.12->dash==0.42.0) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from Flask>=0.12->dash==0.42.0) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from Flask>=0.12->dash==0.42.0) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from Flask>=0.12->dash==0.42.0) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=0.12->dash==0.42.0) (1.1.1)
# Requirement already satisfied: brotli in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from flask-compress->dash==0.42.0) (1.0.9)
# Requirement already satisfied: six in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from plotly->dash==0.42.0) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages (from plotly->dash==0.42.0) (8.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-0.42.0-py3-none-any.whl size=45299 sha256=816c8e44adc7e0947abf2a582975cba26ed6f881f376080f905dae44d1eead5b
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/18/42/a8/39590bcb0b754429b1ff25050a6131c018503d164c2e51f1b7
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-0.47.0-py3-none-any.whl size=4429538 sha256=b83073d9a3b329d4eca64eed1a9e7e3ec17769c7e65b82d5a39a4a690163623c
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/5b/a6/4c/2afac56f5fd8b218ab956d30f617f826a1e30a42bc80b9ca8e
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-0.16.0-py3-none-any.whl size=781507 sha256=2095a2580574ef0c4290b2411644d936e0941c268cb329341646b2f4f4c1054a
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/7e/b3/62/35716c80c50a541ecf658f25ca701fafeea0523d7c762da7b5
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-0.23.0-py3-none-any.whl size=2362483 sha256=b01e3293fd57d5940a802c1357ce2cfa8338cd615787ff50dd93942626802a44
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/42/ff/e4/876298f99bfe9c1e32b9650d5d9c76230c983c1840eb589255
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-3.6.0-py3-none-any.whl size=472762 sha256=99440937e40ff1610a6211c13f1a82ec133b8912d1ae5bfb0ba0e42371d3c5b2
#   Stored in directory: /Users/meilanloh/Library/Caches/pip/wheels/d0/5b/68/6d25fcc56732071144dca88dbb635a0d2df8acc637e0509e0d
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: dash-table, dash-renderer, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     target=lambda: _watch.watch(
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash_renderer/__pycache__/__init__.cpython-38.pyc'
#   Attempting uninstall: dash-renderer
#     Found existing installation: dash-renderer 0.20.0
#     Uninstalling dash-renderer-0.20.0:
#       Successfully uninstalled dash-renderer-0.20.0
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     target=lambda: _watch.watch(
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash_html_components/__pycache__/__init__.cpython-38.pyc'
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     target=lambda: _watch.watch(
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash_html_components/__pycache__/Abbr.cpython-38.pyc.140626629483056'
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.0.0
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     target=lambda: _watch.watch(
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash_html_components/__pycache__/Table.cpython-38.pyc.140626768923968'
# Exception in thread Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-25Thread-44:
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# :
# Traceback (most recent call last):
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     self.run()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     :type dev_tools_ui: bool
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     self._target(*self._args, **self._kwargs)
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1284, in <lambda>
#     :type dev_tools_ui: bool
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     :type dev_tools_ui: bool
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 35, in watch
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/html/Dialog.py'
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/dcc/Graph.py'
#     walk()
#   File "/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/_watch.py", line 20, in walk
#     info = os.stat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/meilanloh/opt/anaconda3/lib/python3.8/site-packages/dash/long_callback/managers/__init__.py'
#     Uninstalling dash-2.0.0:
#       Successfully uninstalled dash-2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dash-bootstrap-components 1.0.0 requires dash>=2.0.0, but you have dash 0.42.0 which is incompatible.
# Successfully installed dash-0.42.0 dash-core-components-0.47.0 dash-html-components-0.16.0 dash-renderer-0.23.0 dash-table-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# data manipulation
import pandas as pd

# plotly 
import plotly.express as px
import plotly.graph_objects as go
# dashboards
import dash 
from jupyter_dash import JupyterDash #for running the dashboard in jupyter notebook
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output, Input
import dash_bootstrap_components as dbc #for dashboard themes

import numpy as np

# %%
app = JupyterDash(__name__,external_stylesheets = [dbc.themes.BOOTSTRAP])

# read the data
data = pd.read_csv('schedule.csv')

# list of all unique teams
teams=data['opponent_name'].unique()

#list of all unique quarters
data['quarter']=pd.PeriodIndex(data.datetime, freq='Q')
q= data['quarter'].unique()


app.layout = html.Div([
    
    # top left drop menu for teams
    html.Div([
            dcc.Dropdown(
                id='team_value',
                options=[{'label': i, 'value': i} for i in teams],
                value='Teams'
            )
    ], style={'width': '48%', 'display': 'inline-block'}), 
    
    # top right drop menu for teams
    html.Div([
            dcc.Dropdown(
                id='quarter_value',
                options=[{'label': i.strftime('%YQ%q'), 'value': i.strftime('%YQ%q')} for i in q],
                value='Quarter'
            )
    ], style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),

#     dcc.Graph(id='cumdist-graphic',
#     dcc.Slider(
#         id='year--slider',
#         min=df['Year'].min(),
#         max=df['Year'].max(),
#         value=df['Year'].min(),
#         marks={str(year): str(year) for year in df['Year'].unique()},
#         step=None
#     )
])

# @app.callback(
#     Output('cumdist-graphic', 'figure'),
#     Input('team_value', 'value'),
#     Input('quarter_value', 'value'))

# def update_graph(team_value, quarter_value):
    
#     colors = ['gray']*len(teams)
#     if team_value !='Teams':
#         index=np.where(teams == team_value)[0][0]
#         colors[index]='aqua'
    
#     fig = go.Figure()

#     for i,team in enumerate(teams):

#         d=data[data['opponent_name']==team].sort_values(by='datetime')
#         if quarter_value !='Quarter':
#             d=d[d['quarter']==quarter_value]
#         dt=d['distance_traveled']
#         cd=np.cumsum(dt)

#         fig.add_trace(go.Scatter(x = d['datetime'], 
#                                  y = cd,
#                                  mode = 'lines',
#                                  name=team,
#                                      line = dict(color = colors[i])
#                                  ))

#     return fig
    
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash app running on http://127.0.0.1:8050/
